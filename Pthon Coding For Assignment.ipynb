  
# Create the pandas DataFrame 
df = pd.DataFrame(data, columns = ['date','level-current','level-chained','change-current','change-chained']) 
  
# print dataframe. 
df.head()
# Out:
#    date  level-current  level-chained  change-current  change-chained
# 0  1948          274.8         2020.0            -0.7            -0.6
# 1  1949          272.8         2008.9            10.0             8.7
# 2  1950          300.2         2184.0            15.7             8.0
# 3  1951          347.3         2360.0             5.9             4.1
# 4  1952          367.7         2456.1             6.0             4.7

# %%
# Dataframe for Unemployment
# Import pandas library 
import pandas as pd
  
# initialize list of lists 
data_unemp = [[1948,3.75],[1949,6.05],[1950,5.20833333333333],[1951,3.28333333333333],[1952,3.025],[1953,2.925],[1954,5.59166666666667],[1955,4.36666666666667],[1956,4.125],[1957,4.3],[1958,6.84166666666667],[1959,5.45],[1960,5.54166666666667],[1961,6.69166666666667],[1962,5.56666666666667],[1963,5.64166666666667],[1964,5.15833333333333],[1965,4.50833333333333],[1966,3.79166666666667],[1967,3.84166666666667],[1968,3.55833333333333],[1969,3.49166666666667],[1970,4.98333333333333],[1971,5.95],[1972,5.6],[1973,4.85833333333333],[1974,5.64166666666667],[1975,8.475],[1976,7.7],[1977,7.05],[1978,6.06666666666667],[1979,5.85],[1980,7.175],[1981,7.61666666666667],[1982,9.70833333333333],[1983,9.6],[1984,7.50833333333333],[1985,7.19166666666667],[1986,7],[1987,6.175],[1988,5.49166666666667],[1989,5.25833333333333],[1990,5.61666666666667],[1991,6.85],[1992,7.49166666666667],[1993,6.90833333333333],[1994,6.1],[1995,5.59166666666667],[1996,5.40833333333333],[1997,4.94166666666667],[1998,4.5],[1999,4.21666666666667],[2000,3.96666666666667],[2001,4.74166666666667],[2002,5.78333333333333],[2003,5.99166666666667],[2004,5.54166666666667],[2005,5.08333333333333],[2006,4.60833333333333],[2007,4.61666666666667],[2008,5.8],[2009,9.28333333333333],[2010,9.60833333333333],[2011,8.93333333333333],[2012,8.075],[2013,7.35833333333333],[2014,6.15833333333333],[2015,5.275],[2016,4.875]] 
  
# Create the pandas DataFrame 
df_unemp = pd.DataFrame(data_unemp, columns = ['date', 'unemployment']) 
  
# print dataframe first 5 rows. 
df_unemp.head()

# selecting rows based on condition 
df_range = df_unemp.loc[df_unemp['unemployment'] > 8.5]
print(df_range)
# Out:
#     date  unemployment
# 34  1982      9.708333
# 35  1983      9.600000
# 61  2009      9.283333
# 62  2010      9.608333
# 63  2011      8.933333

# %%
import pandas as pd
from bokeh.plotting import figure, output_file, show,output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
def make_dashboard(x, gdp_change, unemployment, title, file_name):
    output_file(file_name)
    p = figure(title=title, x_axis_label='year', y_axis_label='%')
    p.line(x.squeeze(), gdp_change.squeeze(), color="firebrick", line_width=4, legend="% GDP change")
    p.line(x.squeeze(), unemployment.squeeze(), line_width=4, legend="% unemployed")
    show(p)
    

# Create your dataframe with column date
# initialize list of lists 
date_list = [1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016]
x_df =  pd.DataFrame(date_list, columns = ['date']) 


# Create your dataframe with column change-current
change_current = [-0.7,10,15.7,5.9,6,0.3,8.9,5.6,5.5,1.5,8.4,4,3.7,7.4,5.6,7.4,8.4,9.6,5.7,9.4,8.2,5.5,8.5,9.8,11.4,8.4,9,11.2,11.1,13,11.7,8.8,12.2,4.3,8.7,11.1,7.5,5.5,6,7.9,7.7,5.7,3.3,5.9,5.2,6.3,4.8,5.7,6.2,5.7,6.3,6.5,3.2,3.4,4.8,6.6,6.7,6,4.6,1.8,-1.8,3.8,3.7,4.2,3.6,4.4,4,2.7,4.2]
change_current_df = pd.DataFrame(change_current, columns = ['change-current']) 

# Create your dataframe with column unemployment
unemployment = [3.75,6.05,5.20833333333333,3.28333333333333,3.025,2.925,5.59166666666667,4.36666666666667,4.125,4.3,6.84166666666667,5.45,5.54166666666667,6.69166666666667,5.56666666666667,5.64166666666667,5.15833333333333,4.50833333333333,3.79166666666667,3.84166666666667,3.55833333333333,3.49166666666667,4.98333333333333,5.95,5.6,4.85833333333333,5.64166666666667,8.475,7.7,7.05,6.06666666666667,5.85,7.175,7.61666666666667,9.70833333333333,9.6,7.50833333333333,7.19166666666667,7,6.175,5.49166666666667,5.25833333333333,5.61666666666667,6.85,7.49166666666667,6.90833333333333,6.1,5.59166666666667,5.40833333333333,4.94166666666667,4.5,4.21666666666667,3.96666666666667,4.74166666666667,5.78333333333333,5.99166666666667,5.54166666666667,5.08333333333333,4.60833333333333,4.61666666666667,5.8,9.28333333333333,9.60833333333333,8.93333333333333,8.075,7.35833333333333,6.15833333333333,5.275,4.875]
unemployment_df = pd.DataFrame(unemployment, columns = ['unemployment']) 

# Give your dashboard a string title
title = 'Dashboard GDP & Unemployment'

file_name = "index.html"
make_dashboard(x=x_df, gdp_change=change_current_df, unemployment=unemployment_df, title='GDP & Unemployment', file_name="index.html")
# Out:
#   <div class="bk-root" id="c40387a7-0fcc-4934-bc1c-2ee30e61b0c9" data-root-id="2203"></div>
